# %% [markdown]
# # Embedding a ML model into a web Application
#
# We dont want to train our model every time. One option for model persistence is the built-in Pickle module allowing for dserialization/de-serialization of Python objects so that we can save our model in its current state and reload if we want to classify new samples. w/o the need to learn the model from the training data all over again.

# %%
import os; import pickle
dest =  os.path.join('movieclassifier', 'pkl_objects') # creates 'movieclassifier\\pkl_objects'
if not os.path.exists(dest):
    os.makedirs(dest)
pickle.dump(stop, open(os.path.join(dest, 'stopwords.pkl'), 'wb'), protocol= 4) 
pickle.dump(clf, open(os.path.join(dest, 'classifier_pkl'), 'wb'), protocol= 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-feb0994acc49> in <module>()
#       3 if not os.path.exists(dest):
#       4     os.makedirs(dest)
# ----> 5 pickle.dump(stop, open(os.path.join(dest, 'stopwords.pkl'), 'wb'), protocol= 4)
#       6 pickle.dump(clf, open(os.path.join(dest, 'classifier_pkl'), 'wb'), protocol= 4)
#
# NameError: name 'stop' is not defined

# %% [markdown]
# Via the pickles we serialized the trained logistic regression model as well as the stop word set from the NLTK library so we dont have to install it on our server. #  protocol = 4 chooses latest and most efficient pickle protocol that has been added to Python 3.4

# %%
import pickle
import os
import re
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import SGDClassifier


stop = stopwords.words('english')


def tokenizer(text):
    text = re.sub('<[^>]*>', '', text)
    emoticons = re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)', text.lower())
    text = re.sub('[\W]+', ' ', text.lower()) +\
        ' '.join(emoticons).replace('-', '')
    tokenized = [w for w in text.split() if w not in stop]
    return tokenized

vect = HashingVectorizer(decode_error='ignore',
                         n_features=2**21,
                         preprocessor=None,
                         tokenizer=tokenizer)

clf = SGDClassifier(loss='log', random_state=1, n_iter=1)


df = pd.read_csv('https://github.com/rasbt/python-machine-learning-book/blob/master/code/ch09/pickle-test-scripts/movie_data_small.csv'
                 , encoding='utf-8', error_bad_lines=False, )

#df.loc[:100, :].to_csv('./movie_data_small.csv', index=None)


X_train = df['review'].values
y_train = df['sentiment'].values

X_train = vect.transform(X_train)
clf.fit(X_train, y_train)

pickle.dump(stop,
            open('stopwords.pkl', 'wb'),
            protocol=4)

pickle.dump(clf,
            open('classifier.pkl', 'wb'),
            protocol=4)
# Out:
# Skipping line 104: expected 1 fields, saw 3
# Skipping line 114: expected 1 fields, saw 3
# Skipping line 116: expected 1 fields, saw 3
# Skipping line 118: expected 1 fields, saw 3
# Skipping line 120: expected 1 fields, saw 3
# Skipping line 125: expected 1 fields, saw 3
# Skipping line 126: expected 1 fields, saw 3
# Skipping line 198: expected 1 fields, saw 2
# Skipping line 213: expected 1 fields, saw 2
# Skipping line 425: expected 1 fields, saw 2
# Skipping line 502: expected 1 fields, saw 14
# Skipping line 507: expected 1 fields, saw 15
# Skipping line 512: expected 1 fields, saw 12
# Skipping line 522: expected 1 fields, saw 4
# Skipping line 527: expected 1 fields, saw 5
# Skipping line 532: expected 1 fields, saw 20
# Skipping line 537: expected 1 fields, saw 7
# Skipping line 542: expected 1 fields, saw 7
# Skipping line 547: expected 1 fields, saw 6
# Skipping line 557: expected 1 fields, saw 11
# Skipping line 562: expected 1 fields, saw 11
# ...
